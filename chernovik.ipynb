# %% [markdown]
# ### 1. Подготовка данных

# %% [markdown]
# Набор данных состоит из фоторафий кранов в папке "kran"

# %% [markdown]
# Шаг 1. Разметка с помощью программы Labelimg https://github.com/tzutalin/labelImg

# %% [markdown]
# Шаг 2. Генератор данных

# %%
import os

os.chdir(r"C:\Users\Aigerim\Desktop\проект\kran")
filelist = os.listdir()

print("Количество изображений крана = ", len(filelist), "\n")
print("имена изображений:")
for i in filelist:
    print(i, end= '\n')
# Out:
# Количество изображений крана =  570
#
# имена изображений:
# 1000_json.xml
# 1012_json.xml
# 1017_json.xml
# 103_json.xml
# 1041_json.xml
# 1047_json.xml
# 1062_json.xml
# 1080_json.xml
# 1085_json.xml
# 1096_json.xml
# 109_json.xml
# 1108_json.xml
# 1124_json.xml
# 1131_json.xml
# 1138_json.xml
# 1156_json.xml
# 1174_json.xml
# 1190_json.xml
# 1198_json.xml
# 120_json.xml
# 1213_json.xml
# 1221_json.xml
# 1222_json.xml
# 1228_json.xml
# 1231_json.xml
# 1246_json.xml
# 1253_json.xml
# 1261_json.xml
# 126_json.xml
# 1287_json.xml
# 1293_json.xml
# 1296_json.xml
# 1305_json.xml
# 1309_json.xml
# 1315_json.xml
# 1326_json.xml
# 1338_json.xml
# 1349_json.xml
# 1365_json.xml
# 1372_json.xml
# 1393_json.xml
# 1396_json.xml
# 1412_json.xml
# 1424_json.xml
# 1427_json.xml
# 142_json.xml
# 1430_json.xml
# 1434_json.xml
# 1447_json.xml
# 1453_json.xml
# 1456_json.xml
# 1462_json.xml
# 1477_json.xml
# 148_json.xml
# 1493_json.xml
# 151_json.xml
# 1523_json.xml
# 1533_json.xml
# 1544_json.xml
# ...

# %%
print(os.getcwd())
# Out:
# C:\Users\Aigerim\Desktop\проект\kran

# %%
#(работа с xml файлом)
import lxml.etree.ElementTree as ET‭

tree‭ = ‬ET.parse‭('‬items.xml‭')
 root‭ = ‬tree.getroot‭()

#‭ ‬общее количество элементов
 print(len(root‭[‬0‭]))
# Out:
#   File "<ipython-input-93-7eea2becbdfd>", line 2
#     import lxml.etree.ElementTree as ET‭
#                                        ^
# SyntaxError: invalid character in identifier

# %%
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator 
import numpy as np
import glob
from PIL import *
import PIL
from scipy import ndimage
def data_gen(path,save_path):
    datagen=ImageDataGenerator(width_shift_range=100,height_shift_range=100)
    file_paths = glob.glob(path)
    for image_path in file_paths:
        #image = np.expand_dims(ndimage.imread(image_path), 0)
        image = Image.open(image_path)
        image = np.expand_dims(image, 0)
        datagen.fit(image)
        for x, val in zip(datagen.flow(image,
            save_to_dir=save_path,     
             save_prefix='aug',       
            save_format='jpeg'),range(10)) :    
            pass
augment_data(r"C:\Users\Aigerim\Desktop\проект\kran\*.xml",r"C:\Users\Aigerim\Desktop\проект\project_kran",)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-87-a67ef646d03b> in <module>
#      18             save_format='jpeg'),range(10)) :
#      19             pass
# ---> 20 augment_data(r"C:\Users\Aigerim\Desktop\проект\kran\*.xml",r"C:\Users\Aigerim\Desktop\проект\project_kran",)
#
# <ipython-input-64-d4904f9e166e> in augment_data(path, save_path)
#      11     for image_path in file_paths:
#      12         #image = np.expand_dims(ndimage.imread(image_path), 0)
# ---> 13         image = Image.open(image_path)
#      14         image = np.expand_dims(image, 0)
#      15         datagen.fit(image)
#
# ~\Anaconda3\envs\env\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2966         warnings.warn(message)
#    2967     raise UnidentifiedImageError(
# -> 2968         "cannot identify image file %r" % (filename if filename else fp)
#    2969     )
# ...

# %%
import cv2
#print(os.getcwd())

   # image_path =i
image = cv2.imread('1000_json.xml')
#print(image)
print("Image shape:", image)
resized = cv2.resize(image, (600, 300))
print("Image shape:", resized.shape)

    #cv2.imshow("image", image)
    #cv2.imshow("resized", resized)
    #cv2.waitKey()
# Out:
# Image shape: None
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-86-6844e9cb25f0> in <module>
#       6 #print(image)
#       7 print("Image shape:", image)
# ----> 8 resized = cv2.resize(image, (600, 300))
#       9 print("Image shape:", resized.shape)
#      10
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-6uw63ony\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
